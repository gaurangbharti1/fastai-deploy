# %%
#hide
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 4.1.5 requires pyqt5<5.13; python_version >= "3", which is not installed.
# spyder 4.1.5 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# voila 0.2.10 requires nbconvert<7,>=6.0.0, but you have nbconvert 5.6.1 which is incompatible.

# %%
from fastbook import *
from fastai.vision.widgets import *

# %%
import urllib.request

# %%
MODEL_URL = "https://www.dropbox.com/s/az08lhvrdqbpssp/export.pkl?dl=1"
urllib.request.urlretrieve(MODEL_URL, "model.pkl")
# Out:
# ('model.pkl', <http.client.HTTPMessage at 0x2429224cfa0>)

# %%
learner_inf = load_learner(Path("."), "model.pkl")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-17-024175250e4f> in <module>
# ----> 1 learner_inf = load_learner(Path("."), "model.pkl")
#
# D:\Anaconda3\envs\tf-gpu\lib\site-packages\fastai\learner.py in load_learner(fname, cpu, pickle_module)
#     379     "Load a `Learner` object in `fname`, optionally putting it on the `cpu`"
#     380     distrib_barrier()
# --> 381     res = torch.load(fname, map_location='cpu' if cpu else None, pickle_module=pickle_module)
#     382     if hasattr(res, 'to_fp32'): res = res.to_fp32()
#     383     if cpu: res.dls.cpu()
#
# D:\Anaconda3\envs\tf-gpu\lib\site-packages\torch\serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     577         pickle_load_args['encoding'] = 'utf-8'
#     578
# --> 579     with _open_file_like(f, 'rb') as opened_file:
#     580         if _is_zipfile(opened_file):
#     581             # The zipfile reader is going to advance the current file position.
#
# D:\Anaconda3\envs\tf-gpu\lib\site-packages\torch\serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# D:\Anaconda3\envs\tf-gpu\lib\site-packages\torch\serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# PermissionError: [Errno 13] Permission denied: '.'

# %%
learn_inf.predict('animals/cat/cat.jpg')
# Out:
# ('cat', tensor(0), tensor([1.0000e+00, 2.9642e-09, 2.1304e-07]))

# %%
learn_inf.dls.vocab
# Out:
# ['cat', 'dog', 'horse']

# %%
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
img = PILImage.create(btn_upload.data[-1])
img
# Out:
# PILImage mode=RGB size=1100x628

# %%
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128, 128))
out_pl
# Out:
# Output()

# %%
pred, pred_idx, probs = learn_inf.predict(img)

# %%
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]: .04f}'
lbl_pred
# Out:
# Label(value='Prediction: dog; Probability:  1.0000')

# %%
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
def on_click_classify(change):
  img = PILImage.create(btn_upload.data[-1])
  out_pl.clear_output()
  with out_pl: display(img.to_thumb(128, 128))
  pred, pred_idx, probs = learn_inf.predict(img)
  lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
btn_upload = widgets.FileUpload()

# %%
VBox([widgets.Label('Select your animal!'),
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your animal!'), FileUpload(value={}, description='Upload'), Button(descript…

# %%
# !pip install voila
# !jupyter serverextension enable --sys-prefix voila
# Out:
# Requirement already satisfied: voila in d:\anaconda3\envs\tf-gpu\lib\site-packages (0.2.10)
# Requirement already satisfied: nbclient<0.6,>=0.4.0 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from voila) (0.5.1)
# Requirement already satisfied: jupyter-server<2.0.0,>=0.3.0 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from voila) (1.8.0)
# Requirement already satisfied: jupyter-client<7,>=6.1.3 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from voila) (6.1.7)
# Requirement already satisfied: jupyter-core>=4.6.0 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (4.7.1)
# Requirement already satisfied: tornado>=4.1 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (6.1)
# Requirement already satisfied: python-dateutil>=2.1 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (2.8.1)
# Requirement already satisfied: traitlets in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (5.0.5)
# Requirement already satisfied: pyzmq>=13 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jupyter-client<7,>=6.1.3->voila) (20.0.0)
# Requirement already satisfied: pywin32>=1.0 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<7,>=6.1.3->voila) (227)
# Requirement already satisfied: argon2-cffi in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (20.1.0)
# Requirement already satisfied: terminado>=0.8.3 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.9.4)
# Requirement already satisfied: jinja2 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (2.11.3)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 4.1.5 requires pyqt5<5.13; python_version >= "3", which is not installed.
# spyder 4.1.5 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# nbdev 1.1.14 requires nbconvert<6, but you have nbconvert 6.0.7 which is incompatible.
# Requirement already satisfied: nbformat in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (5.1.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (3.1.0)
# Requirement already satisfied: websocket-client in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (1.0.1)
# Requirement already satisfied: Send2Trash in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (1.5.0)
# Requirement already satisfied: prometheus-client in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.10.1)
# Requirement already satisfied: ipython-genutils in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.2.0)
# Requirement already satisfied: idna>=2.8 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=0.3.0->voila) (2.10)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=0.3.0->voila) (1.2.0)
# Requirement already satisfied: async-generator in d:\anaconda3\envs\tf-gpu\lib\site-packages (from nbclient<0.6,>=0.4.0->voila) (1.10)
# Requirement already satisfied: nest-asyncio in d:\anaconda3\envs\tf-gpu\lib\site-packages (from nbclient<0.6,>=0.4.0->voila) (1.4.3)
# Collecting nbconvert<7,>=6.0.0
#   Using cached nbconvert-6.0.7-py3-none-any.whl (552 kB)
# Requirement already satisfied: testpath in d:\anaconda3\envs\tf-gpu\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.4.4)
# Requirement already satisfied: defusedxml in d:\anaconda3\envs\tf-gpu\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.6.0)
# Requirement already satisfied: pygments>=2.4.1 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (2.7.4)
# Requirement already satisfied: bleach in d:\anaconda3\envs\tf-gpu\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (3.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in d:\anaconda3\envs\tf-gpu\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from nbconvert<7,>=6.0.0->voila) (0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jinja2->jupyter-server<2.0.0,>=0.3.0->voila) (1.1.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (3.0.2)
# Requirement already satisfied: attrs>=17.4.0 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (0.17.3)
# Requirement already satisfied: six>=1.11.0 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (1.15.0)
# Requirement already satisfied: setuptools in d:\anaconda3\envs\tf-gpu\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (52.0.0.post20210125)
# Requirement already satisfied: pywinpty>=0.5 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from terminado>=0.8.3->jupyter-server<2.0.0,>=0.3.0->voila) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from argon2-cffi->jupyter-server<2.0.0,>=0.3.0->voila) (1.14.5)
# Requirement already satisfied: pycparser in d:\anaconda3\envs\tf-gpu\lib\site-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server<2.0.0,>=0.3.0->voila) (2.20)
# Requirement already satisfied: webencodings in d:\anaconda3\envs\tf-gpu\lib\site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (0.5.1)
# Requirement already satisfied: packaging in d:\anaconda3\envs\tf-gpu\lib\site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (20.9)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\anaconda3\envs\tf-gpu\lib\site-packages (from packaging->bleach->nbconvert<7,>=6.0.0->voila) (2.4.7)
# Installing collected packages: nbconvert
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 5.6.1
#     Uninstalling nbconvert-5.6.1:
#       Successfully uninstalled nbconvert-5.6.1
# Successfully installed nbconvert-6.0.7
# Enabling: voila
# - Writing config: D:\Anaconda3\envs\tf-gpu\etc\jupyter
#     - Validating...
#       voila 0.2.10 ok
